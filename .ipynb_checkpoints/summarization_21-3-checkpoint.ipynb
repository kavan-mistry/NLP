# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kavan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from docx import Document

# %%
def tokenize_document(document):
    tokens = word_tokenize(document)
    return tokens

# %%
doc = Document('doc1.docx')

# %%
document_text = ""

# %%
for paragraph in doc.paragraphs:
    document_text += paragraph.text + "\n"

# %%
tokenized_document = tokenize_document(document_text)

# %%
print("Tokenized document:")
print(tokenized_document)
# Out:
# Tokenized document:
# ['Rabindranath', 'Tagore', 'was', 'the', 'first', 'to', 'call', 'Gandhiji', "'Mahatma", ',', "'", 'which', 'means', "'Great", 'Soul', "'", 'in', 'Sanskrit', '.', 'His', 'wise', 'ideas', 'and', 'beliefs', 'led', 'people', 'to', 'respect', 'and', 'call', 'him', "'Mahatma", 'Gandhi', '.', "'", 'His', 'dedication', 'to', 'the', 'country', 'and', 'efforts', 'to', 'turn', 'his', 'ideas', 'into', 'reality', 'make', 'Indians', 'around', 'the', 'world', 'very', 'proud', 'of', 'him', '.', 'According', 'to', 'Mahatma', 'Gandhi', '’', 's', 'biography', ',', 'he', 'was', 'born', 'on', 'October', '2', ',', '1869', ',', 'in', 'Porbandar', ',', 'a', 'coastal', 'town', 'in', 'the', 'present-day', 'Indian', 'state', 'of', 'Gujarat', '.', 'He', 'grew', 'up', 'in', 'a', 'Hindu', 'family', 'and', 'ate', 'basic', 'vegetarian', 'meals', '.', 'His', 'dad', ',', 'Karamchand', 'Uttamchand', 'Gandhi', ',', 'was', 'an', 'important', 'leader', 'in', 'Porbandar', 'State', '.', 'In', 'South', 'Africa', ',', 'he', 'was', 'the', 'first', 'to', 'lead', 'a', 'peaceful', 'protest', 'movement', ',', 'setting', 'him', 'apart', 'from', 'other', 'demonstrators', '.', 'Mahatma', 'Gandhi', 'also', 'introduced', 'the', 'idea', 'of', 'Satyagraha', ',', 'a', 'nonviolent', 'approach', 'to', 'opposing', 'unfairness', '.', 'He', 'devoted', '20', 'years', 'of', 'his', 'life', 'to', 'battling', 'discrimination', 'in', 'South', 'Africa', '.', 'His', 'idea', 'of', "'Ahimsa", ',', "'", 'which', 'means', 'not', 'hurting', 'anyone', ',', 'was', 'widely', 'admired', 'and', 'followed', 'by', 'many', 'influential', 'people', 'worldwide', '.', 'He', 'became', 'an', 'indomitable', 'figure', 'who', 'could', "n't", 'be', 'defeated', 'in', 'any', 'situation', '.', 'Mahatma', 'Gandhi', 'initiated', 'the', "'Khadi", 'Movement', "'", 'to', 'encourage', 'the', 'use', 'of', 'fabrics', 'like', 'khadi', 'or', 'jute', '.', 'This', 'movement', 'was', 'a', 'crucial', 'part', 'of', 'the', 'larger', "'Non-co-operation", 'Movement', ',', "'", 'which', 'advocated', 'for', 'Indian', 'goods', 'and', 'discouraged', 'foreign', 'ones', '.', 'Gandhi', 'strongly', 'supported', 'agriculture', 'and', 'encouraged', 'people', 'to', 'engage', 'in', 'farming', '.', 'He', 'inspired', 'Indians', 'to', 'embrace', 'manual', 'labor', 'and', 'emphasized', 'self-reliance', ',', 'urging', 'them', 'to', 'provide', 'for', 'their', 'needs', 'and', 'lead', 'simple', 'lives', '.', 'He', 'began', 'weaving', 'cotton', 'clothes', 'using', 'the', 'Charkha', 'to', 'reduce', 'dependence', 'on', 'foreign', 'goods', 'and', 'promote', 'Swadeshi', 'products', 'among', 'Indians', '.']

# %%
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kavan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
filtered_document = [word for word in tokenized_document if word.lower() not in stop_words]

# %%
filtered_document
# Out:
# ['Rabindranath',
#  'Tagore',
#  'first',
#  'call',
#  'Gandhiji',
#  "'Mahatma",
#  ',',
#  "'",
#  'means',
#  "'Great",
#  'Soul',
#  "'",
#  'Sanskrit',
#  '.',
#  'wise',
#  'ideas',
#  'beliefs',
#  'led',
#  'people',
#  'respect',
#  'call',
#  "'Mahatma",
#  'Gandhi',
#  '.',
#  "'",
#  'dedication',
#  'country',
#  'efforts',
#  'turn',
#  'ideas',
#  'reality',
#  'make',
#  'Indians',
#  'around',
#  'world',
#  'proud',
#  '.',
#  'According',
#  'Mahatma',
#  'Gandhi',
#  '’',
#  'biography',
#  ',',
#  'born',
#  'October',
#  '2',
#  ',',
#  '1869',
#  ',',
#  'Porbandar',
#  ',',
#  'coastal',
#  'town',
#  'present-day',
#  'Indian',
#  'state',
#  'Gujarat',
#  '.',
#  'grew',
#  'Hindu',
#  'family',
#  'ate',
#  'basic',
#  'vegetarian',
#  'meals',
#  '.',
#  'dad',
#  ',',
#  'Karamchand',
#  'Uttamchand',
#  'Gandhi',
#  ',',
#  'important',
#  'leader',
#  'Porbandar',
#  'State',
#  '.',
#  'South',
#  'Africa',
#  ',',
#  'first',
#  'lead',
#  'peaceful',
#  'protest',
#  'movement',
#  ',',
#  'setting',
#  'apart',
#  'demonstrators',
#  '.',
#  'Mahatma',
#  'Gandhi',
#  'also',
#  'introduced',
#  'idea',
#  'Satyagraha',
#  ',',
#  'nonviolent',
#  'approach',
#  'opposing',
#  'unfairness',
#  '.',
#  'devoted',
#  '20',
#  'years',
#  'life',
#  'battling',
#  'discrimination',
#  'South',
#  'Africa',
#  '.',
#  'idea',
#  "'Ahimsa",
#  ',',
#  "'",
#  'means',
#  'hurting',
#  'anyone',
#  ',',
#  'widely',
#  'admired',
#  'followed',
#  'many',
#  'influential',
#  'people',
#  'worldwide',
#  '.',
#  'became',
#  'indomitable',
#  'figure',
#  'could',
#  "n't",
#  'defeated',
#  'situation',
#  '.',
#  'Mahatma',
#  'Gandhi',
#  'initiated',
#  "'Khadi",
#  'Movement',
#  "'",
#  'encourage',
#  'use',
#  'fabrics',
#  'like',
#  'khadi',
#  'jute',
#  '.',
#  'movement',
#  'crucial',
#  'part',
#  'larger',
#  "'Non-co-operation",
#  'Movement',
#  ',',
#  "'",
#  'advocated',
#  'Indian',
#  'goods',
#  'discouraged',
#  'foreign',
#  'ones',
#  '.',
#  'Gandhi',
#  'strongly',
#  'supported',
#  'agriculture',
#  'encouraged',
#  'people',
#  'engage',
#  'farming',
#  '.',
#  'inspired',
#  'Indians',
#  'embrace',
#  'manual',
#  'labor',
#  'emphasized',
#  'self-reliance',
#  ',',
#  'urging',
#  'provide',
#  'needs',
#  'lead',
#  'simple',
#  'lives',
#  '.',
#  'began',
#  'weaving',
#  'cotton',
#  'clothes',
#  'using',
#  'Charkha',
#  'reduce',
#  'dependence',
#  'foreign',
#  'goods',
#  'promote',
#  'Swadeshi',
#  'products',
#  'among',
#  'Indians',
#  '.']

# %%
word_counts = {}
total_words = len(tokenized_document)

for word in tokenized_document:
#  'Swadeshi': 0.0033003300330033004,
#  'products': 0.0033003300330033004,
#  'among': 0.0033003300330033004}

# %%
from collections import defaultdict
import heapq

# %%
sentence_scores = defaultdict(float)

# %%
sentences = []
current_sentence = []
for word in tokenized_document:
    current_sentence.append(word)
    if word.endswith('.') or word.endswith('!') or word.endswith('?'):
        sentences.append(current_sentence)
        current_sentence = []

# %%
for sentence in sentences:
    for word in sentence:
        sentence_scores[tuple(sentence)] += tf.get(word, 0)

# %%
sentence_scores
# Out:
# defaultdict(float,
#             {('Rabindranath',
#               'Tagore',
#               'was',
#               'the',
#               'first',
#               'to',
#               'call',
#               'Gandhiji',
#               "'Mahatma",
#               ',',
#               "'",
#               'which',
#               'means',
#               "'Great",
#               'Soul',
#               "'",
#               'in',
#               'Sanskrit',
#               '.'): 0.3168316831683168,
#              ('His',
#               'wise',
#               'ideas',
#               'and',
#               'beliefs',
#               'led',
#               'people',
#               'to',
#               'respect',
#               'and',
#               'call',
#               'him',
#               "'Mahatma",
#               'Gandhi',
#               '.'): 0.2475247524752475,
#              ("'",
#               'His',
#               'dedication',
#               'to',
#               'the',
#               'country',
#               'and',
#               'efforts',
#               'to',
#               'turn',
#               'his',
#               'ideas',
#               'into',
#               'reality',
#               'make',
#               'Indians',
#               'around',
#               'the',
#               'world',
#               'very',
#               'proud',
#               'of',
#               'him',
#               '.'): 0.363036303630363,
#              ('According',
#               'to',
#               'Mahatma',
#               'Gandhi',
#               '’',
#               's',
#               'biography',
#               ',',
#               'he',
#               'was',
#               'born',
#               'on',
#               'October',
#               '2',
#               ',',
#               '1869',
#               ',',
#               'in',
#               'Porbandar',
#               ',',
#               'a',
#               'coastal',
#               'town',
#               'in',
#               'the',
#               'present-day',
#               'Indian',
#               'state',
#               'of',
#               'Gujarat',
#               '.'): 0.5247524752475247,
#              ('He',
#               'grew',
#               'up',
#               'in',
#               'a',
#               'Hindu',
#               'family',
#               'and',
#               'ate',
#               'basic',
#               'vegetarian',
#               'meals',
#               '.'): 0.17161716171617158,
#              ('His',
#               'dad',
#               ',',
#               'Karamchand',
#               'Uttamchand',
#               'Gandhi',
#               ',',
#               'was',
#               'an',
#               'important',
#               'leader',
#               'in',
#               'Porbandar',
#               'State',
#               '.'): 0.25742574257425743,
#              ('In',
#               'South',
#               'Africa',
#               ',',
#               'he',
#               'was',
#               'the',
#               'first',
#               'to',
#               'lead',
#               'a',
#               'peaceful',
#               'protest',
#               'movement',
#               ',',
#               'setting',
#               'him',
#               'apart',
#               'from',
#               'other',
#               'demonstrators',
#               '.'): 0.33333333333333326,
#              ('Mahatma',
#               'Gandhi',
#               'also',
#               'introduced',
#               'the',
#               'idea',
#               'of',
#               'Satyagraha',
#               ',',
#               'a',
#               'nonviolent',
#               'approach',
#               'to',
#               'opposing',
#               'unfairness',
#               '.'): 0.27392739273927397,
#              ('He',
#               'devoted',
#               '20',
#               'years',
#               'of',
#               'his',
#               'life',
#               'to',
#               'battling',
#               'discrimination',
#               'in',
#               'South',
#               'Africa',
#               '.'): 0.2013201320132013,
#              ('His',
#               'idea',
#               'of',
#               "'Ahimsa",
#               ',',
#               "'",
#               'which',
#               'means',
#               'not',
#               'hurting',
#               'anyone',
#               ',',
#               'was',
#               'widely',
#               'admired',
#               'and',
#               'followed',
#               'by',
#               'many',
#               'influential',
#               'people',
#               'worldwide',
#               '.'): 0.32343234323432346,
#              ('He',
#               'became',
#               'an',
#               'indomitable',
#               'figure',
#               'who',
#               'could',
#               "n't",
#               'be',
#               'defeated',
#               'in',
#               'any',
#               'situation',
#               '.'): 0.13531353135313529,
#              ('Mahatma',
#               'Gandhi',
#               'initiated',
#               'the',
#               "'Khadi",
#               'Movement',
#               "'",
#               'to',
#               'encourage',
#               'the',
#               'use',
#               'of',
#               'fabrics',
#               'like',
#               'khadi',
#               'or',
#               'jute',
#               '.'): 0.2706270627062707,
#              ('This',
#               'movement',
#               'was',
#               'a',
#               'crucial',
#               'part',
#               'of',
#               'the',
#               'larger',
#               "'Non-co-operation",
#               'Movement',
#               ',',
#               "'",
#               'which',
#               'advocated',
#               'for',
#               'Indian',
#               'goods',
#               'and',
#               'discouraged',
#               'foreign',
#               'ones',
#               '.'): 0.3201320132013201,
#              ('Gandhi',
#               'strongly',
#               'supported',
#               'agriculture',
#               'and',
#               'encouraged',
#               'people',
#               'to',
#               'engage',
#               'in',
#               'farming',
#               '.'): 0.20462046204620463,
#              ('He',
#               'inspired',
#               'Indians',
#               'to',
#               'embrace',
#               'manual',
#               'labor',
#               'and',
#               'emphasized',
#               'self-reliance',
#               ',',
#               'urging',
#               'them',
#               'to',
#               'provide',
#               'for',
#               'their',
#               'needs',
#               'and',
#               'lead',
#               'simple',
#               'lives',
#               '.'): 0.33333333333333337,
#              ('He',
#               'began',
#               'weaving',
#               'cotton',
#               'clothes',
#               'using',
#               'the',
#               'Charkha',
#               'to',
#               'reduce',
#               'dependence',
#               'on',
#               'foreign',
#               'goods',
#               'and',
#               'promote',
#               'Swadeshi',
#               'products',
#               'among',
#               'Indians',
#               '.'): 0.24752475247524755})

# %%
sentence
# Out:
# ['He',
#  'began',
#  'weaving',
#  'cotton',
#  'clothes',
#  'using',
#  'the',
#  'Charkha',
#  'to',
#  'reduce',
#  'dependence',
#  'on',
#  'foreign',
#  'goods',
#  'and',
#  'promote',
#  'Swadeshi',
#  'products',
#  'among',
#  'Indians',
#  '.']

# %%
num_sentences_in_summary = 4
summary_sentences = heapq.nlargest(num_sentences_in_summary, sentence_scores, key=sentence_scores.get)

# %%
summary = ' '.join(' '.join(sentence) for sentence in summary_sentences)

# %%
summary
# Out:
# "According to Mahatma Gandhi ’ s biography , he was born on October 2 , 1869 , in Porbandar , a coastal town in the present-day Indian state of Gujarat . ' His dedication to the country and efforts to turn his ideas into reality make Indians around the world very proud of him . He inspired Indians to embrace manual labor and emphasized self-reliance , urging them to provide for their needs and lead simple lives . In South Africa , he was the first to lead a peaceful protest movement , setting him apart from other demonstrators ."

# %%
num_sentences_in_summary = 2
summary_sentences = heapq.nlargest(num_sentences_in_summary, sentence_scores, key=sentence_scores.get)

# %%
summary = ' '.join(' '.join(sentence) for sentence in summary_sentences)

# %%
summary
# Out:
# "According to Mahatma Gandhi ’ s biography , he was born on October 2 , 1869 , in Porbandar , a coastal town in the present-day Indian state of Gujarat . ' His dedication to the country and efforts to turn his ideas into reality make Indians around the world very proud of him ."
